# %% [markdown]
# # **Cheminformatics in Python [PART 2.2] Predicting Solubility of Molecules using PyCaret | End-to-End Data Science Project**
#
# Chanin Nantasenamat
#
# <i>[Data Professor YouTube channel](http://youtube.com/dataprofessor), http://youtube.com/dataprofessor </i>
#
# In this Jupyter notebook, we will continue our journey into the world of Cheminformatics (i.e. lies at the interface of Informatics and Chemistry) by simplifying this notebook via the use of the low-code machine learning library PyCaret.
#
#
# **Information from the previous notebook:**
#
# We will be reproducing a research article (by John S. Delaney$^1$) by applying Linear Regression to predict the solubility of molecules (i.e. solubility of drugs is an important physicochemical property in Drug discovery, design and development).
#
# This idea for this notebook was inspired by the excellent blog post by Pat Walters$^2$ where he reproduced the linear regression model with similar degree of performance as that of Delaney. This example is also briefly described in the book ***Deep Learning for the Life Sciences: Applying Deep Learning to Genomics, Microscopy, Drug Discovery, and More***.$^3$

# %% [markdown]
# ## **1. Install PyCaret**

# %%
# ! pip install catboost

# %%
# ! pip install pycaret==1.0
# ! pip install pycaret

# %% [markdown]
# ## **2. Read in dataset**

# %%
import pandas as pd

# %%
#delaney_with_descriptors_url = 'https://raw.githubusercontent.com/dataprofessor/data/master/delaney_solubility_with_descriptors.csv'
dataset = pd.read_csv("04_bioactivity_data_3class_pIC50.csv")

# %%
dataset
# Out:
#     Unnamed: 0 molecule_chembl_id  \
# 0            0       CHEMBL187579
# 1            1       CHEMBL188487
# 2            2       CHEMBL185698
# 3            3       CHEMBL426082
# 4            4       CHEMBL187717
# ..         ...                ...
# 81          81      CHEMBL2146517
# 82          82       CHEMBL187460
# 83          83       CHEMBL363535
# 84          84       CHEMBL227075
# 85          85        CHEMBL45830
#
#                                      canonical_smiles bioactivity_class  \
# 0              Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21      intermediate
# 1              O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21      intermediate
# 2             O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21          inactive
# 3                 O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21          inactive
# 4     O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]      intermediate
# ..                                                ...               ...
# 81  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...          inactive
# 82        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C          inactive
# 83             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12          inactive
# 84      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1          inactive
# 85             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C          inactive
#
#          MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0   281.271  1.89262         0.0            5.0  5.142668
# 1   415.589  3.81320         0.0            2.0  5.026872
# 2   421.190  2.66050         0.0            4.0  4.869666
# 3   293.347  3.63080         0.0            3.0  4.882397
# 4   338.344  3.53900         0.0            5.0  5.698970
# ..      ...      ...         ...            ...       ...
# 81  338.359  3.40102         0.0            5.0  4.675718
# 82  296.366  3.44330         0.0            3.0  3.644548
# 83  276.291  4.09564         0.0            3.0  4.412289
# 84  278.307  3.29102         0.0            3.0  4.841638
# 85  282.383  4.10530         0.0            2.0  4.675718
#
# [86 rows x 9 columns]

# %%
dataset_new = dataset[['MW', 'LogP', 'NumHDonors', 'NumHAcceptors', 'pIC50']]
dataset_new
# Out:
#          MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0   281.271  1.89262         0.0            5.0  5.142668
# 1   415.589  3.81320         0.0            2.0  5.026872
# 2   421.190  2.66050         0.0            4.0  4.869666
# 3   293.347  3.63080         0.0            3.0  4.882397
# 4   338.344  3.53900         0.0            5.0  5.698970
# ..      ...      ...         ...            ...       ...
# 81  338.359  3.40102         0.0            5.0  4.675718
# 82  296.366  3.44330         0.0            3.0  3.644548
# 83  276.291  4.09564         0.0            3.0  4.412289
# 84  278.307  3.29102         0.0            3.0  4.841638
# 85  282.383  4.10530         0.0            2.0  4.675718
#
# [86 rows x 5 columns]

# %% [markdown]
# ## **3. Model Building**

# %% [markdown]
# ### **3.1. Model Setup**

# %%
# pip install scikit-learn

# %%
from pycaret.regression import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# i:\My Drive\2022\Bioinformatics\CovidVax\Drug Step Exp1.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/i%3A/My%20Drive/2022/Bioinformatics/CovidVax/Drug%20Step%20Exp1.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> from pycaret.regression import *
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
model = setup(data = dataset_new, target = 'pIC50', train_size=0.8, silent=True)
# Out:
#
# Setup Succesfully Completed!
# <style type="text/css">
# </style>
# <table id="T_1771e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1771e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1771e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1771e_row0_col1" class="data row0 col1" >3999</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1771e_row1_col0" class="data row1 col0" >Transform Target </td>
#       <td id="T_1771e_row1_col1" class="data row1 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1771e_row2_col0" class="data row2 col0" >Transform Target Method</td>
#       <td id="T_1771e_row2_col1" class="data row2 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1771e_row3_col0" class="data row3 col0" >Original Data</td>
#       <td id="T_1771e_row3_col1" class="data row3 col1" >(86, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1771e_row4_col0" class="data row4 col0" >Missing Values </td>
#       <td id="T_1771e_row4_col1" class="data row4 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1771e_row5_col0" class="data row5 col0" >Numeric Features </td>
#       <td id="T_1771e_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1771e_row6_col0" class="data row6 col0" >Categorical Features </td>
#       <td id="T_1771e_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1771e_row7_col0" class="data row7 col0" >Ordinal Features </td>
#       <td id="T_1771e_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1771e_row8_col0" class="data row8 col0" >High Cardinality Features </td>
#       <td id="T_1771e_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1771e_row9_col0" class="data row9 col0" >High Cardinality Method </td>
#       <td id="T_1771e_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1771e_row10_col0" class="data row10 col0" >Sampled Data</td>
#       <td id="T_1771e_row10_col1" class="data row10 col1" >(86, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1771e_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_1771e_row11_col1" class="data row11 col1" >(68, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1771e_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_1771e_row12_col1" class="data row12 col1" >(18, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1771e_row13_col0" class="data row13 col0" >Numeric Imputer </td>
#       <td id="T_1771e_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1771e_row14_col0" class="data row14 col0" >Categorical Imputer </td>
#       <td id="T_1771e_row14_col1" class="data row14 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1771e_row15_col0" class="data row15 col0" >Normalize </td>
#       <td id="T_1771e_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1771e_row16_col0" class="data row16 col0" >Normalize Method </td>
#       <td id="T_1771e_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1771e_row17_col0" class="data row17 col0" >Transformation </td>
#       <td id="T_1771e_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1771e_row18_col0" class="data row18 col0" >Transformation Method </td>
#       <td id="T_1771e_row18_col1" class="data row18 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1771e_row19_col0" class="data row19 col0" >PCA </td>
#       <td id="T_1771e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1771e_row20_col0" class="data row20 col0" >PCA Method </td>
#       <td id="T_1771e_row20_col1" class="data row20 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1771e_row21_col0" class="data row21 col0" >PCA Components </td>
#       <td id="T_1771e_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1771e_row22_col0" class="data row22 col0" >Ignore Low Variance </td>
#       <td id="T_1771e_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1771e_row23_col0" class="data row23 col0" >Combine Rare Levels </td>
#       <td id="T_1771e_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1771e_row24_col0" class="data row24 col0" >Rare Level Threshold </td>
#       <td id="T_1771e_row24_col1" class="data row24 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1771e_row25_col0" class="data row25 col0" >Numeric Binning </td>
#       <td id="T_1771e_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_1771e_row26_col0" class="data row26 col0" >Remove Outliers </td>
#       <td id="T_1771e_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_1771e_row27_col0" class="data row27 col0" >Outliers Threshold </td>
#       <td id="T_1771e_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_1771e_row28_col0" class="data row28 col0" >Remove Multicollinearity </td>
#       <td id="T_1771e_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_1771e_row29_col0" class="data row29 col0" >Multicollinearity Threshold </td>
#       <td id="T_1771e_row29_col1" class="data row29 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_1771e_row30_col0" class="data row30 col0" >Clustering </td>
#       <td id="T_1771e_row30_col1" class="data row30 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1771e_level0_row31" class="row_heading level0 row31" >31

# %% [markdown]
# ### **3.2. Model comparison**
#
# Subsequent blocks of codes here will be using the ``training set`` (the 80% subset) for model building.

# %%
#pip install scikit-learn

# %%
compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=245)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               12:01:18
# Status     . . . . . . . . . . . . . . . . . .   Fitting Fold 5 of 10
# Estimator  . . . . . . . . . . . . . . . . . .        Huber Regressor
# ETC        . . . . . . . . . . . . . . . . . .  0.0 Seconds Remaining
#                            Model     MAE      MSE  ...      R2   RMSLE    MAPE
# 0                 Bayesian Ridge  1.4246   2.8889  ...  0.0018  0.4287  0.7091
# 1               Ridge Regression  1.4181   2.7987  ... -0.0124  0.4102  0.6661
# 2              Linear Regression  1.4200   2.8003  ... -0.0192  0.4089  0.6623
# 3         Least Angle Regression  1.4200   2.8003  ... -0.0192  0.4089  0.6623
# 4                    Elastic Net  1.5953   3.5159  ... -0.0994  0.4869  0.8672
# 5               Lasso Regression  1.6124   3.6243  ... -0.1548  0.4946  0.8949
# 6             TheilSen Regressor  1.4410   3.0749  ... -0.1819  0.4451  0.6210
# 7    Orthogonal Matching Pursuit  1.5851   3.6077  ... -0.2832  0.4936  0.8476
# 8   Lasso Least Angle Regression  1.8080   4.4806  ... -0.4256  0.5352  1.0548
# 9        Random Sample Consensus  1.5004   4.2074  ... -0.6268  0.4111  0.5075
# 10  Passive Aggressive Regressor  2.8902  11.9370  ... -4.1572  0.8805  0.9384
#
# [11 rows x 7 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-9ff5ccfe3077> in <module>()
# ----> 1 compare_models()
#
# /usr/local/lib/python3.7/dist-packages/pycaret/regression.py in compare_models(blacklist, fold, round, sort, turbo)
#    2918             Xtrain,Xtest = data_X.iloc[train_i], data_X.iloc[test_i]
#    2919             ytrain,ytest = data_y.iloc[train_i], data_y.iloc[test_i]
# -> 2920             model.fit(Xtrain,ytrain)
#    2921             pred_ = model.predict(Xtest)
#    2922
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_huber.py in fit(self, X, y, sample_weight)
#     294                              " l-BFGS-b solver terminated with %s"
#     295                              % opt_res.message)
# --> 296         self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
#     297         self.scale_ = parameters[-1]
#     298         if self.fit_intercept:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/optimize.py in _check_optimize_result(solver, result, max_iter, extra_warning_msg)
#     241                 "    https://scikit-learn.org/stable/modules/"
#     242                 "preprocessing.html."
# --> 243             ).format(solver, result.status, result.message.decode("latin1"))
#     244             if extra_warning_msg is not None:
#     245                 warning_msg += "\n" + extra_warning_msg
#
# AttributeError: 'str' object has no attribute 'decode'

# %% [markdown]
# ### **3.3. Model Creation**

# %%
et = create_model('rf')

# %% [markdown]
# ### **3.4. Model Tuning**
#
# The learning parameters are subjected to optimization at this phase. Here, 50 iterations is used for the optimization process and the fitness function is the Mean Absolute Error (MAE) which is the performance metric used to judge at which learning parameter settings are optimal.

# %%
tuned_et = tune_model('rf', n_iter = 50, optimize = 'mae')

# %%
print(tuned_et)

# %% [markdown]
# ### **4. Model Analysis**

# %% [markdown]
# #### **4.1. Plot Models**
# In this tutorial, we are performing regression and so further details of the regression plots are available at https://pycaret.org/plot-model/.

# %% [markdown]
# **Residuals Plot**

# %%
plot_model('rf', 'residuals')

# %% [markdown]
# **Prediction Error Plot**

# %%
plot_model(et, 'error')

# %% [markdown]
# **Cooks Distance Plot**

# %%
plot_model(et, 'cooks')

# %% [markdown]
# **Recursive Feature Selection**

# %%
plot_model('rf', 'rfe')

# %% [markdown]
# **Learning Curve**

# %%
plot_model(et, 'learning')

# %% [markdown]
# **Validation Curve**

# %%
plot_model(et, 'vc')

# %% [markdown]
# **Manifold Learning**

# %%
plot_model(et, 'manifold')

# %% [markdown]
# **Feature Importance**

# %%
plot_model(et, 'feature')

# %% [markdown]
# **Model Hyperparameter**

# %% [markdown]
# The hyperparameter of the learning model is displayed using the ``parameter`` argument in inside the ``plot_model()`` function.

# %%
plot_model(et, 'parameter')

# %% [markdown]
# Here, the hyperparameter of the tuned model is displayed below.

# %%
plot_model(tuned_et, 'parameter')

# %% [markdown]
# **Show all plots**
#
# The ``evaluate_model()`` displays all available plots here.

# %%
evaluate_model(tuned_et)

# %% [markdown]
# #### **4.2. Model Interpretaion**
#
# The ``interpret_model()`` function of PyCaret leverages the use of the SHAP library to produce stunning plots for depicting the **SHAP (SHapley Additive exPlanations)** values that was originally proposed by Lundberg and Lee in 2016.$^5$ In a nutshell, SHAP plots adds interpretability to constructed models so that the contribution of each features to the prediction can be elucidated.

# %% [markdown]
# **Summary Plot**

# %%
interpret_model(et)

# %% [markdown]
# **Correlation Plot**

# %%
interpret_model(et, plot = 'correlation')

# %% [markdown]
# **Reason Plot at Observation Level**
#
# The *Reason Plot at Observation Level* as called by PyCaret is better known as the **force plot** and this plot essentially describes the ***push and pull effect*** that each individual features has on the **base value** that eventually leads to the predicted **output value**.

# %%
interpret_model(et, plot = 'reason', observation = 10)

# %% [markdown]
# ### **6.6. External Testing**
#
# We will now apply the trained model (built with 80% subset) to evaluate on the so-called **"hold-out"** testing set (the 20% subset) that serves as the unseen data.

# %%
prediction_holdout = predict_model(et)

# %%
prediction_holdout.head()

# %% [markdown]
# ---

# %% [markdown]
# ## **Reference**
#
# 1. John S. Delaney. [ESOL:  Estimating Aqueous Solubility Directly from Molecular Structure](https://pubs.acs.org/doi/10.1021/ci034243x). ***J. Chem. Inf. Comput. Sci.*** 2004, 44, 3, 1000-1005.
#
# 2. Pat Walters. [Predicting Aqueous Solubility - It's Harder Than It Looks](http://practicalcheminformatics.blogspot.com/2018/09/predicting-aqueous-solubility-its.html). ***Practical Cheminformatics Blog***
#
# 3. Bharath Ramsundar, Peter Eastman, Patrick Walters, and Vijay Pande. [Deep Learning for the Life Sciences: Applying Deep Learning to Genomics, Microscopy, Drug Discovery, and More](https://learning.oreilly.com/library/view/deep-learning-for/9781492039822/), O'Reilly, 2019.
#
# 4. [Supplementary file](https://pubs.acs.org/doi/10.1021/ci034243x) from Delaney's ESOL:  Estimating Aqueous Solubility Directly from Molecular Structure.
#
# 5. Scott M. Lundberg and Su-In Lee. [A Unified Approach to Interpreting Model Predictions](https://papers.nips.cc/paper/7062-a-unified-approach-to-interpreting-model-predictions), A Unified Approach to Interpreting Model Predictions, ***Advances in Neural Information Processing Systems 30 (NIPS 2017)***, 2017.
