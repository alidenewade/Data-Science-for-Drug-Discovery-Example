# %% [markdown]
# # **Comparing Regressors**

# %% [markdown]
# ## **1. Import libraries**

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## **2. Load the data set**

# %%
df = pd.read_csv('05_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (86, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (86, 186)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:07<00:00,  5.57it/s]
# 100%|██████████| 42/42 [00:00<00:00, 60934.20it/s]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                                               Adjusted R-Squared  ...  Time Taken
# Model                                                                             ...
# Lars                          29801704001024317122330573304299476381978373253...  ...        0.25
# KernelRidge                                                                 2.56  ...        0.06
# LassoLars                                                                   1.56  ...        0.04
# DummyRegressor                                                              1.56  ...        0.02
# LassoLarsIC                                                                 1.27  ...        0.05
# Lasso                                                                       1.24  ...        0.03
# ElasticNet                                                                  1.13  ...        0.04
# LassoLarsCV                                                                 1.13  ...        0.13
# LarsCV                                                                      1.08  ...        0.65
# NuSVR                                                                       1.06  ...        0.02
# KNeighborsRegressor                                                         1.05  ...        0.04
# SVR                                                                         1.05  ...        0.03
# GammaRegressor                                                              1.04  ...        0.03
# HistGradientBoostingRegressor                                               1.04  ...        0.18
# LGBMRegressor                                                               1.04  ...        0.04
# PassiveAggressiveRegressor                                                  1.03  ...        0.03
# GeneralizedLinearRegressor                                                  1.03  ...        0.06
# TweedieRegressor                                                            1.03  ...        0.03
# LassoCV                                                                     1.03  ...        1.93
# ElasticNetCV                                                                1.03  ...        1.88
# OrthogonalMatchingPursuitCV                                                 1.03  ...        0.05
# OrthogonalMatchingPursuit                                                   1.02  ...        0.02
# AdaBoostRegressor                                                           1.02  ...        0.10
# PoissonRegressor                                                            1.02  ...        0.04
# BaggingRegressor                                                            1.01  ...        0.04
# BayesianRidge                                                               1.01  ...        0.03
# RandomForestRegressor                                                       1.01  ...        0.26
# SGDRegressor                                                                1.01  ...        0.04
# RidgeCV                                                                     1.01  ...        0.05
# GradientBoostingRegressor                                                   1.00  ...        0.15
# Ridge                                                                       1.00  ...        0.03
# HuberRegressor                                                              1.00  ...        0.12
# MLPRegressor                                                                1.00  ...        0.22
# LinearSVR                                                                   1.00  ...        0.12
# LinearRegression                                                            1.00  ...        0.04
# TransformedTargetRegressor                                                  1.00  ...        0.03
# XGBRegressor                                                                1.00  ...        0.22
# GaussianProcessRegressor                                                    1.00  ...        0.04
# ExtraTreeRegressor                                                          1.00  ...        0.04
# DecisionTreeRegressor                                                       1.00  ...        0.03
# ExtraTreesRegressor                                                         1.00  ...        0.25
#
# [41 rows x 4 columns]

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
# Empty DataFrame
# Columns: [Adjusted R-Squared, R-Squared, RMSE, Time Taken]
# Index: []

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
